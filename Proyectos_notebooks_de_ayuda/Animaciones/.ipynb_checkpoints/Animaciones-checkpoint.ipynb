# %% [markdown]
# # Animaciones
# Para realizar una simulación, es necesario ver una secuencia de gráficas en forma de video. Para esto podemos guardar cada imagen con un nombre diferente usando el símbolo $\$$, por ejemplo:

# %%
using Plots

# %% [markdown]
# Para poder hacer simulaciones en tiempo real usando Plots, primero tenemos que pedir a nuestro graficador que "nos muestre" lo que se graficará, limpiando cada vez el gui (donde se grafica) incluso si está dentro de un ciclo for o while. Para esto, ponemos la instrucción "show = true" dentro de los paréntesis del graficador interno de plots que usaremos. Por ejemplo: gr(show = true).
#
# Esta instrucción es óptima si se usa desde la terminal, sin embargo, en ijulia no funciona. Si estamos dentro de un notebook, tenemos que usar la instrucción "show = :ijulia".

# %%
Pkg.add("GR")
# Out:
# INFO: Package GR is already installed
# INFO: METADATA is out-of-date — you may not have the latest version of GR
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
gr(show = :ijulia)
# Out:
# Plots.GRBackend()

# %%
x = 0:0.01:2*pi
for i in 1:200
    plot(x, sin.(x + i / 10.0))
    savefig("sinx$i.png")
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3500)" points="
# 45.7332,375.813 580.315,375.813 580.315,11.811 45.7332,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="536" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,370.353 45.7332,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   130.858,370.353 130.858,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   215.982,370.353 215.982,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   301.107,370.353 301.107,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   386.231,370.353 386.231,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   471.356,370.353 471.356,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   556.48,370.353 556.48,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,330.313 572.296,330.313
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,284.813 572.296,284.813
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,239.313 572.296,239.313
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,193.812 572.296,193.812
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,148.312 572.296,148.312
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,102.812 572.296,102.812
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,57.3114 572.296,57.3114
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,11.811
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   130.858,375.813 130.858,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   215.982,375.813 215.982,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   301.107,375.813 301.107,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   386.231,375.813 386.231,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   471.356,375.813 471.356,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   556.48,375.813 556.48,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,330.313 53.7519,330.313
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,284.813 53.7519,284.813
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,239.313 53.7519,239.313
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,193.812 53.7519,193.812
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,148.312 53.7519,148.312
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,102.812 53.7519,102.812
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,57.3114 53.7519,57.3114
#   "/>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.7332, 389.613)" x="45.7332" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 130.858, 389.613)" x="130.858" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 215.982, 389.613)" x="215.982" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 301.107, 389.613)" x="301.107" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 386.231, 389.613)" x="386.231" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 471.356, 389.613)" x="471.356" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 556.48, 389.613)" x="556.48" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 334.813)" x="39.7332" y="334.813">-0.75</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 289.313)" x="39.7332" y="289.313">-0.50</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 243.813)" x="39.7332" y="243.813">-0.25</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12

# %% [markdown]
# __Nota:__ Si al compilar les sale el siguiente error:
#
# IOPub data rate exceeded.<br>
# The notebook server will temporarily stop sending output<br>
# to the client in order to avoid crashing it.<br>
# To change this limit, set the config variable<br>
# `--NotebookApp.iopub_data_rate_limit`.<br>
#
# Para abrir el notebook en la terminal deben usar:
#
# jupyter notebook --NotebookApp.iopub_data_rate_limit=10000000000

# %% [markdown]
# Esta versión de hacer un video es útil si queremos hacer una simulación cuyo resultado sea un video de varios minutos. Para obtener un video corto,usaremos dos tipos de macros:
#
# * @gif que sirve para generar un gif animado el cual muestra en el notebook y guarda como "tmp.gif". En este caso el gif se reproduce con 10fps.
# * @animate genera también un gif animado, pero esta vez lo guarda con el nombre que se desee y los fps que se quieran.
#
# Ejemplos:

# %%
x = 0:0.01:2*pi
@gif for i=1:100
    plot(x, sin.(x + i / 10.0), key = false)
end every 2 #guarda sólo cada 20 cuadros
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3500)" points="
# 45.7332,375.813 580.315,375.813 580.315,11.811 45.7332,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="536" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,370.353 45.7332,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   130.858,370.353 130.858,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   215.982,370.353 215.982,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   301.107,370.353 301.107,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   386.231,370.353 386.231,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   471.356,370.353 471.356,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   556.48,370.353 556.48,17.2711
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,330.315 572.296,330.315
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,284.814 572.296,284.814
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,239.313 572.296,239.313
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,193.813 572.296,193.813
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,148.312 572.296,148.312
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,102.812 572.296,102.812
#   "/>
# <polyline clip-path="url(#clip3502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,57.3109 572.296,57.3109
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,11.811
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   130.858,375.813 130.858,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   215.982,375.813 215.982,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   301.107,375.813 301.107,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   386.231,375.813 386.231,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   471.356,375.813 471.356,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   556.48,375.813 556.48,370.353
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,330.315 53.7519,330.315
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,284.814 53.7519,284.814
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,239.313 53.7519,239.313
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,193.813 53.7519,193.813
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,148.312 53.7519,148.312
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,102.812 53.7519,102.812
#   "/>
# <polyline clip-path="url(#clip3500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,57.3109 53.7519,57.3109
#   "/>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.7332, 389.613)" x="45.7332" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 130.858, 389.613)" x="130.858" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 215.982, 389.613)" x="215.982" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 301.107, 389.613)" x="301.107" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 386.231, 389.613)" x="386.231" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 471.356, 389.613)" x="471.356" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 556.48, 389.613)" x="556.48" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 334.815)" x="39.7332" y="334.815">-0.75</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 289.314)" x="39.7332" y="289.314">-0.50</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 243.813)" x="39.7332" y="243.813">-0.25</text>
# </g>
# <g clip-path="url(#clip3500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12
# INFO: Saved animation to /home/lorena/Fisica_computacional_2018-1/Proyectos_notebooks_de_ayuda/Animaciones/tmp.gif
# Plots.AnimatedGif("/home/lorena/Fisica_computacional_2018-1/Proyectos_notebooks_de_ayuda/Animaciones/tmp.gif")

# %%
x = 0:0.01:2*pi
anim = @animate for i=1:20
    plot(x, sin.(x + i / 10.0), key = false)
end
gif(anim, "anim_fps15.gif", fps = 15)
gif(anim, "anim_fps5.gif", fps = 5)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 45.7332,375.813 580.315,375.813 580.315,11.811 45.7332,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="536" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,370.353 45.7332,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   130.858,370.353 130.858,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   215.982,370.353 215.982,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   301.107,370.353 301.107,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   386.231,370.353 386.231,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   471.356,370.353 471.356,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   556.48,370.353 556.48,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,330.313 572.296,330.313
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,284.813 572.296,284.813
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,239.312 572.296,239.312
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,193.812 572.296,193.812
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,148.311 572.296,148.311
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,102.811 572.296,102.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,57.3101 572.296,57.3101
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,11.811
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   130.858,375.813 130.858,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   215.982,375.813 215.982,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   301.107,375.813 301.107,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   386.231,375.813 386.231,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   471.356,375.813 471.356,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   556.48,375.813 556.48,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,330.313 53.7519,330.313
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,284.813 53.7519,284.813
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,239.312 53.7519,239.312
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,193.812 53.7519,193.812
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,148.311 53.7519,148.311
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,102.811 53.7519,102.811
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,57.3101 53.7519,57.3101
#   "/>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.7332, 389.613)" x="45.7332" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 130.858, 389.613)" x="130.858" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 215.982, 389.613)" x="215.982" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 301.107, 389.613)" x="301.107" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 386.231, 389.613)" x="386.231" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 471.356, 389.613)" x="471.356" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 556.48, 389.613)" x="556.48" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 334.813)" x="39.7332" y="334.813">-0.75</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 289.313)" x="39.7332" y="289.313">-0.50</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 243.812)" x="39.7332" y="243.812">-0.25</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12
# INFO: Saved animation to /home/lorena/Fisica_computacional_2018-1/Proyectos_notebooks_de_ayuda/Animaciones/anim_fps15.gif
# INFO: Saved animation to /home/lorena/Fisica_computacional_2018-1/Proyectos_notebooks_de_ayuda/Animaciones/anim_fps5.gif
# Plots.AnimatedGif("/home/lorena/Fisica_computacional_2018-1/Proyectos_notebooks_de_ayuda/Animaciones/anim_fps5.gif")

# %% [markdown]
# Por último, a veces las animaciones en tiempo real son demasiado rápidas, pues el cálculo que se requiere hacer para graficar cada paso de la simulación dura milisegundos. Esto conlleva a animaciones que no se ven bien. Para esto se puede usar la función "sleep(t)" que detiene cualquier cálculo durante el tiempo  $t$  (en segundos) que se deseé.
#
# Ejemplo:

# %%
x = 0:0.01:2*pi
for i in 1:200 
    plot(x, sin.(x + i / 10.0), key =false)
    sleep(0.1)
end
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 45.7332,375.813 580.315,375.813 580.315,11.811 45.7332,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="11" width="536" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.7332,370.353 45.7332,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   130.858,370.353 130.858,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   215.982,370.353 215.982,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   301.107,370.353 301.107,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   386.231,370.353 386.231,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   471.356,370.353 471.356,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   556.48,370.353 556.48,17.2711
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,330.313 572.296,330.313
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,284.813 572.296,284.813
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,239.313 572.296,239.313
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,193.812 572.296,193.812
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,148.312 572.296,148.312
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,102.812 572.296,102.812
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   53.7519,57.3114 572.296,57.3114
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,11.811
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,375.813 45.7332,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   130.858,375.813 130.858,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   215.982,375.813 215.982,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   301.107,375.813 301.107,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   386.231,375.813 386.231,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   471.356,375.813 471.356,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   556.48,375.813 556.48,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,330.313 53.7519,330.313
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,284.813 53.7519,284.813
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,239.313 53.7519,239.313
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,193.812 53.7519,193.812
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,148.312 53.7519,148.312
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,102.812 53.7519,102.812
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.7332,57.3114 53.7519,57.3114
#   "/>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.7332, 389.613)" x="45.7332" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 130.858, 389.613)" x="130.858" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 215.982, 389.613)" x="215.982" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 301.107, 389.613)" x="301.107" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 386.231, 389.613)" x="386.231" y="389.613">4</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 471.356, 389.613)" x="471.356" y="389.613">5</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 556.48, 389.613)" x="556.48" y="389.613">6</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 334.813)" x="39.7332" y="334.813">-0.75</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 289.313)" x="39.7332" y="289.313">-0.50</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 39.7332, 243.813)" x="39.7332" y="243.813">-0.25</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12
